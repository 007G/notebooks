# %% [markdown]
# <a href="https://colab.research.google.com/github/007G/notebooks/blob/main/interactive-demos/gradcam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Grad-CAM
# This example interactively demonstrates Grad-CAM using nnabla's pre-trained model.
#
# [Ramprasaath R. Selvaraju, Michael Cogswell, Abhishek Das, Ramakrishna Vedantam, Devi Parikh, Dhruv Batra. Grad-CAM: Visual explanations from deep networks via gradient-based localization. Proceedings of the IEEE International conference on computer vision, pages 618 - 626, 2017.](https://openaccess.thecvf.com/content_iccv_2017/html/Selvaraju_Grad-CAM_Visual_Explanations_ICCV_2017_paper.html)

# %% [markdown]
# Where does machine learning look at images to make decisions? This paper describes Grad-CAM, an algorithm that uses heat maps to indicate the image areas used as the basis for judgment in image classification by CNN [R.R. Selvaraju + 2016]. The principle behind Grad-CAM is to visualize the information on which the decision is based by displaying the location of the large input gradient to the final convolution layer. Grad-CAM allows you to visualize areas of relevance for each prediction class. In the final output, the gradient is backpropagated, with only the specified class being 1 and the other classes being 0, to find the gradient in the feature map. Uses the average slope on each channel as a weight, and adds that weight to the values in the feature map. The Grad-CAM is computed through the activation function ReLU to remove the negative part. The feature is that the operation is very light, so it can be operated at high speed. As an example of application, we can see where the misclassified images were judged. It can also detect cases where misclassification occurs due to gender differences.
#
# ![Grad-CAM algorithm](https://github.com/sony/nnabla-examples/raw/master/responsible_ai/gradcam/images/grad-cam_fig.png)

# %% [markdown]
# # Preparation
# Let's start by installing nnabla and accessing [nnabla-examples repository](https://github.com/sony/nnabla-examples). If you're running on Colab, make sure that your Runtime setting is set as GPU, which can be set up from the top menu (Runtime → change runtime type), and make sure to click **Connect** on the top right-hand side of the screen before you start.

# %%
# May show warnings for newly imported packages if run in Colab default python environment.
# Please click the `RESTART RUNTIME` to run the following script correctly.
# The error message of conflicts is acceptable.
# !pip install nnabla-ext-cuda116
# !git clone https://github.com/sony/nnabla-examples.git
# Out:
# Collecting nnabla-ext-cuda116
#   Downloading nnabla_ext_cuda116-1.36.0-cp310-cp310-manylinux_2_17_x86_64.whl (123.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.6/123.6 MB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nnabla-ext-cuda116) (67.7.2)
# Collecting nnabla==1.36.0 (from nnabla-ext-cuda116)
#   Downloading nnabla-1.36.0-cp310-cp310-manylinux_2_17_x86_64.whl (17.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.7/17.7 MB 66.7 MB/s eta 0:00:00
# Requirement already satisfied: Cython in /usr/local/lib/python3.10/dist-packages (from nnabla==1.36.0->nnabla-ext-cuda116) (3.0.5)
# Collecting numpy~=1.24.0 (from nnabla==1.36.0->nnabla-ext-cuda116)
#   Downloading numpy-1.24.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 70.7 MB/s eta 0:00:00
# Collecting boto3 (from nnabla==1.36.0->nnabla-ext-cuda116)
#   Downloading boto3-1.28.85-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 19.8 MB/s eta 0:00:00
# Collecting configparser (from nnabla==1.36.0->nnabla-ext-cuda116)
#   Downloading configparser-6.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: contextlib2 in /usr/local/lib/python3.10/dist-packages (from nnabla==1.36.0->nnabla-ext-cuda116) (21.6.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from nnabla==1.36.0->nnabla-ext-cuda116) (3.9.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from nnabla==1.36.0->nnabla-ext-cuda116) (6.0.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from nnabla==1.36.0->nnabla-ext-cuda116) (1.11.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from nnabla==1.36.0->nnabla-ext-cuda116) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nnabla==1.36.0->nnabla-ext-cuda116) (4.66.1)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from nnabla==1.36.0->nnabla-ext-cuda116) (2.31.6)
# Requirement already satisfied: pillow>=9.1.0 in /usr/local/lib/python3.10/dist-packages (from nnabla==1.36.0->nnabla-ext-cuda116) (9.4.0)
# Collecting ply (from nnabla==1.36.0->nnabla-ext-cuda116)
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 8.3 MB/s eta 0:00:00
# Collecting protobuf<=3.19.6 (from nnabla==1.36.0->nnabla-ext-cuda116)
#   Downloading protobuf-3.19.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 86.5 MB/s eta 0:00:00
# Collecting botocore<1.32.0,>=1.31.85 (from boto3->nnabla==1.36.0->nnabla-ext-cuda116)
#   Downloading botocore-1.31.85-py3-none-any.whl (11.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 96.2 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->nnabla==1.36.0->nnabla-ext-cuda116)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.8.0,>=0.7.0 (from boto3->nnabla==1.36.0->nnabla-ext-cuda116)
#   Downloading s3transfer-0.7.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore<1.32.0,>=1.31.85->boto3->nnabla==1.36.0->nnabla-ext-cuda116) (2.8.2)
# Requirement already satisfied: urllib3<2.1,>=1.25.4 in /usr/local/lib/python3.10/dist-packages (from botocore<1.32.0,>=1.31.85->boto3->nnabla==1.36.0->nnabla-ext-cuda116) (2.0.7)
# Installing collected packages: ply, protobuf, numpy, jmespath, configparser, botocore, s3transfer, boto3, nnabla, nnabla-ext-cuda116
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# tensorflow 2.14.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 3.19.6 which is incompatible.
# tensorflow-datasets 4.9.3 requires protobuf>=3.20, but you have protobuf 3.19.6 which is incompatible.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 3.19.6 which is incompatible.
# Successfully installed boto3-1.28.85 botocore-1.31.85 configparser-6.0.0 jmespath-1.0.1 nnabla-1.36.0 nnabla-ext-cuda116-1.36.0 numpy-1.24.4 ply-3.11 protobuf-3.19.6 s3transfer-0.7.0
# Cloning into 'nnabla-examples'...
# remote: Enumerating objects: 9643, done.
# remote: Counting objects: 100% (2201/2201), done.
# remote: Compressing objects: 100% (880/880), done.
# remote: Total 9643 (delta 1280), reused 2117 (delta 1261), pack-reused 7442
# Receiving objects: 100% (9643/9643), 298.96 MiB | 35.27 MiB/s, done.
# Resolving deltas: 100% (5244/5244), done.
# Updating files: 100% (1711/1711), done.

# %%
# %cd nnabla-examples/responsible_ai/gradcam
# Out:
# /content/nnabla-examples/responsible_ai/gradcam

# %% [markdown]
# Import dependencies

# %%
import os
import cv2
import urllib.request
import numpy as np
import matplotlib.pyplot as plt
import nnabla as nn
from nnabla.utils.image_utils import imread
from nnabla.models.imagenet import VGG16

from gradcam import gradcam
from gradcam import overlay_images

from nnabla.ext_utils import get_extension_context
ctx = get_extension_context('cudnn')
nn.set_default_context(ctx)

# %% [markdown]
# ## Image Preparation
# Download image to apply Grad-CAM for.

# %%
url = 'https://upload.wikimedia.org/wikipedia/commons/4/4e/A_crab_spider_on_a_flower_preying_upon_a_euglossine_bee%2C_while_a_butterfly_looks_for_nectar.jpg'
img_path = 'input_flower_moth_spider.jpg'
if not os.path.isfile(img_path):
    tgt = urllib.request.urlopen(url).read()
    with open(img_path, mode='wb') as f:
        f.write(tgt)

# %% [markdown]
# Take a look at what the image looks like.
# We can see a flower in the middle on which a butterfly rests.

# %%
img = imread(img_path, size=(224, 224), channel_first=True)
plt.imshow(img.transpose(1,2,0))
plt.show()

# %% [markdown]
# ## Network Definition
# Loading the model is very simple.<br>
# You can choose other models such as `VGG11`, `VGG13`, by specifying the model's name as an argument. Of course, you can choose other pretrained models as well. See the [Docs](https://nnabla.readthedocs.io/en/latest/python/api/models/imagenet.html).
#
# **NOTE**: If you use the `VGG16` for the first time, nnabla will automatically download the weights from `https://nnabla.org` and it may take up to a few minutes.

# %%
model = VGG16()
# Out:
# VGG-16.nnp: 100%|██████████| 528M/528M [02:06<00:00, 4.36MB/s]
# Loading /root/nnabla_data/nnp_models/imagenet/VGG-16.nnp.

# %%
batch_size = 1
x = nn.Variable((batch_size,) + model.input_shape)
# set training True since gradient of variable is necessary for Grad-CAM
vgg = model(x, training=True, returns_net=True)
vgg_variables = vgg.variables

# %% [markdown]
# We now define the input, and extract the necessary outputs.
# middle_layer: the last convolution layer
# pred: final output of the model

# %%
target_label_indices = {
    'butterfly': 326,# lycaenid, lycaenid butterfly
    'flower': 985,# daisy
    'spider': 74,# garden spider
}

input_name = list(vgg.inputs.keys())[0]
vgg_variables[input_name].d = img
middle_layer = vgg_variables['VGG16/ReLU_13']
pred = vgg_variables["VGG16/Affine_3"]
selected = pred[:, target_label_indices['butterfly']]

# %% [markdown]
# Let's see how the model predicted the image.
# We can see the model classified the image as we expect.
# Labels regarding butterfly comes high, while flower is also recognized although it is14th ranked probability.

# %%
selected.forward()

# %%
predicted_labels = np.argsort(-pred.d[0])
for i, predicted_label in enumerate(predicted_labels[:15]):
        print(f'Top {i+1}, Label index: {predicted_label},  Label name: {model.category_names[predicted_label]}')
# Out:
# Top 1, Label index: 94,  Label name: hummingbird
# Top 2, Label index: 323,  Label name: monarch, monarch butterfly, milkweed butterfly, Danaus plexippus
# Top 3, Label index: 321,  Label name: admiral
# Top 4, Label index: 326,  Label name: lycaenid, lycaenid butterfly
# Top 5, Label index: 716,  Label name: picket fence, paling
# Top 6, Label index: 738,  Label name: pot, flowerpot
# Top 7, Label index: 301,  Label name: ladybug, ladybeetle, lady beetle, ladybird, ladybird beetle
# Top 8, Label index: 304,  Label name: leaf beetle, chrysomelid
# Top 9, Label index: 489,  Label name: chainlink fence
# Top 10, Label index: 950,  Label name: orange
# Top 11, Label index: 309,  Label name: bee
# Top 12, Label index: 580,  Label name: greenhouse, nursery, glasshouse
# Top 13, Label index: 723,  Label name: pinwheel
# Top 14, Label index: 316,  Label name: cicada, cicala
# Top 15, Label index: 310,  Label name: ant, emmet, pismire

# %% [markdown]
# ## Grad-CAM Computation

# %% [markdown]
# Execute backward computation to calculate gradient to use for Grad-CAM.

# %%
selected.backward()

# %% [markdown]
# Let's compute the heatmap using the gradient with respect to the last convolution layer.

# %%
heatmap = gradcam(middle_layer)

# %% [markdown]
# ## Visualization
# Take a look at how the heatmap looks like in the layer of interest.

# %%
plt.matshow(heatmap)
plt.show()

# %% [markdown]
# Then we overlay the heatmap onto the original image to understand where the model focused.

# %%
base_img = imread(img_path, size=(224, 224))
overlaid_img_butterfly = overlay_images(base_img, heatmap)

# %% [markdown]
# Now we overlay the heatmap onto the original image to understand where the model focused.
# We can speculate the model recognized the butterfly, focusing on its wing.

# %%
plt.imshow(overlaid_img_butterfly)
plt.show()

# %% [markdown]
# Let's use flower as the label of interest to see how the model see the image this time by calculating Grad-CAM.

# %% [markdown]
# Reset gradient first.

# %%
for k, v in vgg_variables.items():
    if 'VGG16/' in k:
        v.grad.zero()

# %% [markdown]
# Calculate gradient and Grad-CAM same as for butterfly.

# %%
selected_daisy = pred[:, target_label_indices['flower']]
selected_daisy.backward()

# %%
heatmap_daisy = gradcam(middle_layer)
plt.matshow(heatmap_daisy)
plt.show()

# %% [markdown]
# We can see the model focus is widely spread comparing to than for butterfly as if the heatmap wrapped the flower.

# %%
overlaid_img_daisy = overlay_images(base_img, heatmap_daisy)
plt.imshow(overlaid_img_daisy)
plt.show()

# %% [markdown]
# Finally, compare images in oneline to enable to see the differences clearly.

# %%
images = {
    'original': base_img,
    'butterfly': overlaid_img_butterfly,
    'flower': overlaid_img_daisy,
}


row = 1
col = len(images)
fig, axes = plt.subplots(row, col, figsize=(15,15))

for i, (k, v) in enumerate(images.items()):
    axes[i].imshow(v)
    axes[i].set_title(k)
